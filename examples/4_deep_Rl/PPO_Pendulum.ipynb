# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
import torch

# %%
if torch.cuda.is_available():
    dev = "cuda:0"
elif torch.backends.mps.is_available():
    dev = "mps"
else:
    dev = "cpu"
device = torch.device(dev)
device
# Out:
# device(type='mps')

# %%
device = torch.device("cpu")
device
# Out:
# device(type='cpu')

# %%
env = env = make_vec_env("Pendulum-v1", n_envs=4)

# %%
model = PPO("MlpPolicy", env, verbose=1, device=device)
model.learn(total_timesteps=500_000)
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -1.2e+03 |
# | time/              |          |
# |    fps             | 40698    |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 8192     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.19e+03    |
# | time/                   |              |
# |    fps                  | 14221        |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0036733733 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.00158      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.13e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00192     |
# |    std                  | 0.977        |
# |    value_loss           | 6.76e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.2e+03     |
# | time/                   |              |
# |    fps                  | 11697        |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0022597208 |
# |    clip_fraction        | 0.00513      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.0114       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.95e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000505    |
# |    std                  | 0.964        |
# |    value_loss           | 6.03e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.23e+03   |
# | time/                   |             |
# |    fps                  | 10718       |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.002039033 |
# |    clip_fraction        | 0.0126      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.0013      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.01e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.000571   |
# |    std                  | 0.964       |
# |    value_loss           | 6.79e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.23e+03    |
# | time/                   |              |
# |    fps                  | 10246        |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0031115958 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000603     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.82e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00147     |
# |    std                  | 0.96         |
# |    value_loss           | 5.46e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 9955        |
# |    iterations           | 6           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.002090244 |
# |    clip_fraction        | 0.00707     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.000186    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.04e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00039    |
# |    std                  | 0.966       |
# |    value_loss           | 5.58e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.16e+03    |
# | time/                   |              |
# |    fps                  | 9758         |
# |    iterations           | 7            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0032962128 |
# |    clip_fraction        | 0.0253       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.000101     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.6e+03      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00232     |
# |    std                  | 0.948        |
# |    value_loss           | 4.44e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.16e+03   |
# | time/                   |             |
# |    fps                  | 9617        |
# |    iterations           | 8           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.002199422 |
# |    clip_fraction        | 0.0082      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 6.32e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.000395   |
# |    std                  | 0.935       |
# |    value_loss           | 3.46e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.14e+03    |
# | time/                   |              |
# |    fps                  | 9501         |
# |    iterations           | 9            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0019411771 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 3.3e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13e+03     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00112     |
# |    std                  | 0.932        |
# |    value_loss           | 3.24e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.15e+03    |
# | time/                   |              |
# |    fps                  | 9404         |
# |    iterations           | 10           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0025868854 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 2.03e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 782          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000801    |
# |    std                  | 0.938        |
# |    value_loss           | 2.54e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.12e+03    |
# | time/                   |              |
# |    fps                  | 9308         |
# |    iterations           | 11           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0023690285 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 9.48e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 845          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00042     |
# |    std                  | 0.946        |
# |    value_loss           | 2.54e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.1e+03     |
# | time/                   |              |
# |    fps                  | 9214         |
# |    iterations           | 12           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0020503232 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 7.81e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 511          |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000227    |
# |    std                  | 0.953        |
# |    value_loss           | 1.64e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 9133         |
# |    iterations           | 13           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0015212619 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 4.47e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 539          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000325    |
# |    std                  | 0.945        |
# |    value_loss           | 1.68e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 9093         |
# |    iterations           | 14           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0024024444 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 5.3e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 461          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000956    |
# |    std                  | 0.954        |
# |    value_loss           | 1.46e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.13e+03    |
# | time/                   |              |
# |    fps                  | 9058         |
# |    iterations           | 15           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0036806152 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 5.6e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 281          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00201     |
# |    std                  | 0.964        |
# |    value_loss           | 1.18e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.1e+03    |
# | time/                   |             |
# |    fps                  | 9026        |
# |    iterations           | 16          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.004637576 |
# |    clip_fraction        | 0.0352      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.112       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 352         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00211    |
# |    std                  | 0.941       |
# |    value_loss           | 931         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 8973         |
# |    iterations           | 17           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0030148956 |
# |    clip_fraction        | 0.0144       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.405        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 182          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000526    |
# |    std                  | 0.92         |
# |    value_loss           | 694          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.06e+03    |
# | time/                   |              |
# |    fps                  | 8947         |
# |    iterations           | 18           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0026227646 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.601        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 139          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0011      |
# |    std                  | 0.908        |
# |    value_loss           | 435          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -1.07e+03    |
# | time/                   |              |
# |    fps                  | 8921         |
# |    iterations           | 19           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 155648       |
# | train/                  |              |
# |    approx_kl            | 0.0042484826 |
# |    clip_fraction        | 0.0362       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.656        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 206          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0023      |
# |    std                  | 0.896        |
# |    value_loss           | 423          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.09e+03   |
# | time/                   |             |
# |    fps                  | 8904        |
# |    iterations           | 20          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.003575069 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.697       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 83.6        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00268    |
# |    std                  | 0.896       |
# |    value_loss           | 463         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.06e+03   |
# | time/                   |             |
# |    fps                  | 8884        |
# |    iterations           | 21          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.005381805 |
# |    clip_fraction        | 0.0523      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 194         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0039     |
# |    std                  | 0.895       |
# |    value_loss           | 357         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -1.02e+03   |
# | time/                   |             |
# |    fps                  | 8873        |
# |    iterations           | 22          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.005369165 |
# |    clip_fraction        | 0.0412      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93          |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00396    |
# |    std                  | 0.878       |
# |    value_loss           | 198         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -969        |
# | time/                   |             |
# |    fps                  | 8863        |
# |    iterations           | 23          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.005571611 |
# |    clip_fraction        | 0.0504      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.6        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00328    |
# |    std                  | 0.872       |
# |    value_loss           | 190         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -939        |
# | time/                   |             |
# |    fps                  | 8856        |
# |    iterations           | 24          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.005277613 |
# |    clip_fraction        | 0.0539      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 67.6        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00591    |
# |    std                  | 0.878       |
# |    value_loss           | 187         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -889        |
# | time/                   |             |
# |    fps                  | 8850        |
# |    iterations           | 25          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.008763457 |
# |    clip_fraction        | 0.0799      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.2        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00859    |
# |    std                  | 0.861       |
# |    value_loss           | 139         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -845         |
# | time/                   |              |
# |    fps                  | 8835         |
# |    iterations           | 26           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0130163655 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.899        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43.6         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00994     |
# |    std                  | 0.835        |
# |    value_loss           | 159          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -785        |
# | time/                   |             |
# |    fps                  | 8831        |
# |    iterations           | 27          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.010056607 |
# |    clip_fraction        | 0.0974      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 121         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00904    |
# |    std                  | 0.831       |
# |    value_loss           | 171         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -716        |
# | time/                   |             |
# |    fps                  | 8826        |
# |    iterations           | 28          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.013470533 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.6        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.833       |
# |    value_loss           | 157         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -644         |
# | time/                   |              |
# |    fps                  | 8822         |
# |    iterations           | 29           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 237568       |
# | train/                  |              |
# |    approx_kl            | 0.0130231865 |
# |    clip_fraction        | 0.144        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.885        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 115          |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0146      |
# |    std                  | 0.825        |
# |    value_loss           | 206          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -538       |
# | time/                   |            |
# |    fps                  | 8818       |
# |    iterations           | 30         |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 245760     |
# | train/                  |            |
# |    approx_kl            | 0.01399932 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.21      |
# |    explained_variance   | 0.904      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 85.3       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0162    |
# |    std                  | 0.807      |
# |    value_loss           | 222        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -411        |
# | time/                   |             |
# |    fps                  | 8812        |
# |    iterations           | 31          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.013396701 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 112         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.776       |
# |    value_loss           | 270         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -291        |
# | time/                   |             |
# |    fps                  | 8804        |
# |    iterations           | 32          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.010756954 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.5        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.747       |
# |    value_loss           | 228         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -237        |
# | time/                   |             |
# |    fps                  | 8795        |
# |    iterations           | 33          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.011351383 |
# |    clip_fraction        | 0.0964      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.7        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00633    |
# |    std                  | 0.715       |
# |    value_loss           | 127         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -188        |
# | time/                   |             |
# |    fps                  | 8776        |
# |    iterations           | 34          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.005810993 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32          |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.000695   |
# |    std                  | 0.693       |
# |    value_loss           | 76.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -185        |
# | time/                   |             |
# |    fps                  | 8769        |
# |    iterations           | 35          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.008610161 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00173     |
# |    std                  | 0.684       |
# |    value_loss           | 47.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -201         |
# | time/                   |              |
# |    fps                  | 8765         |
# |    iterations           | 36           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0077618724 |
# |    clip_fraction        | 0.0628       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.8         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000653    |
# |    std                  | 0.669        |
# |    value_loss           | 41.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -209        |
# | time/                   |             |
# |    fps                  | 8755        |
# |    iterations           | 37          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.005385736 |
# |    clip_fraction        | 0.0545      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.6        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00126    |
# |    std                  | 0.669       |
# |    value_loss           | 44.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -202        |
# | time/                   |             |
# |    fps                  | 8752        |
# |    iterations           | 38          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.005274358 |
# |    clip_fraction        | 0.0514      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.2        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00341    |
# |    std                  | 0.685       |
# |    value_loss           | 88.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -195        |
# | time/                   |             |
# |    fps                  | 8750        |
# |    iterations           | 39          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.006033553 |
# |    clip_fraction        | 0.058       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.7        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00473    |
# |    std                  | 0.682       |
# |    value_loss           | 73.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -175         |
# | time/                   |              |
# |    fps                  | 8749         |
# |    iterations           | 40           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0058498834 |
# |    clip_fraction        | 0.0698       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.3         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.00119      |
# |    std                  | 0.678        |
# |    value_loss           | 37.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -179        |
# | time/                   |             |
# |    fps                  | 8749        |
# |    iterations           | 41          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 335872      |
# | train/                  |             |
# |    approx_kl            | 0.006196346 |
# |    clip_fraction        | 0.0745      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.52        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00117     |
# |    std                  | 0.658       |
# |    value_loss           | 18.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -173         |
# | time/                   |              |
# |    fps                  | 8748         |
# |    iterations           | 42           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0049289693 |
# |    clip_fraction        | 0.0547       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.993       |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6            |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000715     |
# |    std                  | 0.649        |
# |    value_loss           | 18.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -177        |
# | time/                   |             |
# |    fps                  | 8748        |
# |    iterations           | 43          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 352256      |
# | train/                  |             |
# |    approx_kl            | 0.008041985 |
# |    clip_fraction        | 0.0818      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.976      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.71        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00222     |
# |    std                  | 0.643       |
# |    value_loss           | 11.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -184         |
# | time/                   |              |
# |    fps                  | 8747         |
# |    iterations           | 44           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0075965784 |
# |    clip_fraction        | 0.0809       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.97        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.7         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 0.00218      |
# |    std                  | 0.637        |
# |    value_loss           | 13.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -168        |
# | time/                   |             |
# |    fps                  | 8744        |
# |    iterations           | 45          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.006771786 |
# |    clip_fraction        | 0.0627      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.91        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00173    |
# |    std                  | 0.62        |
# |    value_loss           | 23.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -167         |
# | time/                   |              |
# |    fps                  | 8742         |
# |    iterations           | 46           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0067670774 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.927       |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.22         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.00333      |
# |    std                  | 0.606        |
# |    value_loss           | 8.31         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -178        |
# | time/                   |             |
# |    fps                  | 8740        |
# |    iterations           | 47          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.009872657 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.905      |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.29        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00134     |
# |    std                  | 0.594       |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -166        |
# | time/                   |             |
# |    fps                  | 8737        |
# |    iterations           | 48          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.009971108 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.89       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.44        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.000479    |
# |    std                  | 0.588       |
# |    value_loss           | 13.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -163       |
# | time/                   |            |
# |    fps                  | 8737       |
# |    iterations           | 49         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 401408     |
# | train/                  |            |
# |    approx_kl            | 0.01054569 |
# |    clip_fraction        | 0.0963     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.863     |
# |    explained_variance   | 0.991      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.542      |
# |    n_updates            | 480        |
# |    policy_gradient_loss | 0.0043     |
# |    std                  | 0.563      |
# |    value_loss           | 8.93       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -161        |
# | time/                   |             |
# |    fps                  | 8736        |
# |    iterations           | 50          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.007952843 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.9        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.00201     |
# |    std                  | 0.557       |
# |    value_loss           | 13.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -167        |
# | time/                   |             |
# |    fps                  | 8735        |
# |    iterations           | 51          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 417792      |
# | train/                  |             |
# |    approx_kl            | 0.013420386 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.84       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.8        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00115     |
# |    std                  | 0.561       |
# |    value_loss           | 17.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -180       |
# | time/                   |            |
# |    fps                  | 8734       |
# |    iterations           | 52         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 425984     |
# | train/                  |            |
# |    approx_kl            | 0.01884013 |
# |    clip_fraction        | 0.0879     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.835     |
# |    explained_variance   | 0.991      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.1       |
# |    n_updates            | 510        |
# |    policy_gradient_loss | 0.00193    |
# |    std                  | 0.553      |
# |    value_loss           | 14.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -171        |
# | time/                   |             |
# |    fps                  | 8733        |
# |    iterations           | 53          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 434176      |
# | train/                  |             |
# |    approx_kl            | 0.008213045 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.807      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.6         |
# |    n_updates            | 520         |
# |    policy_gradient_loss | 0.00203     |
# |    std                  | 0.534       |
# |    value_loss           | 10.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -168         |
# | time/                   |              |
# |    fps                  | 8731         |
# |    iterations           | 54           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0062090955 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.78        |
# |    explained_variance   | 0.992        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.403        |
# |    n_updates            | 530          |
# |    policy_gradient_loss | 0.00459      |
# |    std                  | 0.523        |
# |    value_loss           | 7.5          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -160        |
# | time/                   |             |
# |    fps                  | 8730        |
# |    iterations           | 55          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 450560      |
# | train/                  |             |
# |    approx_kl            | 0.018059568 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.41        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.00191     |
# |    std                  | 0.529       |
# |    value_loss           | 6.41        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -160         |
# | time/                   |              |
# |    fps                  | 8728         |
# |    iterations           | 56           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0073084887 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.774       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.15         |
# |    n_updates            | 550          |
# |    policy_gradient_loss | 0.00257      |
# |    std                  | 0.522        |
# |    value_loss           | 6.05         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -148        |
# | time/                   |             |
# |    fps                  | 8727        |
# |    iterations           | 57          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.007224487 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.76       |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.38        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | 0.00464     |
# |    std                  | 0.515       |
# |    value_loss           | 3.39        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -137        |
# | time/                   |             |
# |    fps                  | 8727        |
# |    iterations           | 58          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.008462917 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.749      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.4        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | 0.00262     |
# |    std                  | 0.51        |
# |    value_loss           | 7.59        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -139         |
# | time/                   |              |
# |    fps                  | 8726         |
# |    iterations           | 59           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 483328       |
# | train/                  |              |
# |    approx_kl            | 0.0044549936 |
# |    clip_fraction        | 0.108        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.741       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.436        |
# |    n_updates            | 580          |
# |    policy_gradient_loss | 0.00174      |
# |    std                  | 0.507        |
# |    value_loss           | 4.66         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -141        |
# | time/                   |             |
# |    fps                  | 8726        |
# |    iterations           | 60          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.009720849 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.737      |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.213       |
# |    n_updates            | 590         |
# |    policy_gradient_loss | 0.00275     |
# |    std                  | 0.502       |
# |    value_loss           | 6.64        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -161        |
# | time/                   |             |
# |    fps                  | 8725        |
# |    iterations           | 61          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.008543164 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.719      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.803       |
# |    n_updates            | 600         |
# |    policy_gradient_loss | 0.00416     |
# |    std                  | 0.494       |
# |    value_loss           | 4.72        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -167        |
# | time/                   |             |
# |    fps                  | 8725        |
# |    iterations           | 62          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.006221343 |
# |    clip_fraction        | 0.0674      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.704      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.22        |
# |    n_updates            | 610         |
# |    policy_gradient_loss | 0.000727    |
# |    std                  | 0.487       |
# |    value_loss           | 6.28        |
# -----------------------------------------

# %%
test_env = gym.make("Pendulum-v1")

num_eval_episodes = 100
episode_rewards = []

for episode in range(num_eval_episodes):
    state, _ = test_env.reset()
    done = False
    total_reward = 0.0

    while not done:
        action, _ = model.predict(state, deterministic=True)
        state, reward, terminated, truncated, _ = test_env.step(action)
        done = terminated or truncated

        total_reward += reward

    episode_rewards.append(total_reward)

test_env.close()

average_reward = sum(episode_rewards) / num_eval_episodes
print(f"Average reward over {num_eval_episodes} episodes: {average_reward:.2f}")
# Out:
# Average reward over 100 episodes: -143.62
