# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
import torch

# %%
if torch.cuda.is_available():
    dev = "cuda:0"
elif torch.backends.mps.is_available():
    dev = "mps"
else:
    dev = "cpu"
device = torch.device(dev)
device
# Out:
# device(type='mps')

# %%
device = torch.device("cpu")
device
# Out:
# device(type='cpu')

# %%
env = env = make_vec_env("CartPole-v1", n_envs=4)

# %%
model = PPO("MlpPolicy", env, verbose=1, device=device)
model.learn(total_timesteps=100_000)
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | 22.2     |
# | time/              |          |
# |    fps             | 30592    |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.1        |
# |    ep_rew_mean          | 32.1        |
# | time/                   |             |
# |    fps                  | 12544       |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014685856 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | 0.00106     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.08        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0264     |
# |    value_loss           | 19          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 55         |
# |    ep_rew_mean          | 55         |
# | time/                   |            |
# |    fps                  | 10586      |
# |    iterations           | 3          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01714251 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.645     |
# |    explained_variance   | 0.419      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.2       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0342    |
# |    value_loss           | 23.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 9843        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.013542864 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | 0.394       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0305     |
# |    value_loss           | 44.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 164         |
# |    ep_rew_mean          | 164         |
# | time/                   |             |
# |    fps                  | 9439        |
# |    iterations           | 5           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.012121072 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.559      |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0157     |
# |    value_loss           | 35.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 210         |
# |    ep_rew_mean          | 210         |
# | time/                   |             |
# |    fps                  | 9160        |
# |    iterations           | 6           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007857511 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.537      |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.05        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00919    |
# |    value_loss           | 18.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 258         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 8976        |
# |    iterations           | 7           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009949995 |
# |    clip_fraction        | 0.095       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.536      |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.52        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00946    |
# |    value_loss           | 8.33        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 311         |
# |    ep_rew_mean          | 311         |
# | time/                   |             |
# |    fps                  | 8864        |
# |    iterations           | 8           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.007832034 |
# |    clip_fraction        | 0.0821      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.519      |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.64        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00779    |
# |    value_loss           | 7.95        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 357         |
# |    ep_rew_mean          | 357         |
# | time/                   |             |
# |    fps                  | 8779        |
# |    iterations           | 9           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.007320881 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.5        |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.29        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 3.42        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 400         |
# | time/                   |             |
# |    fps                  | 8685        |
# |    iterations           | 10          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.007874336 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.482      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.42        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00893    |
# |    value_loss           | 1.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 438         |
# |    ep_rew_mean          | 438         |
# | time/                   |             |
# |    fps                  | 8643        |
# |    iterations           | 11          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004043062 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.466      |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.202       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00595    |
# |    value_loss           | 0.803       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 469          |
# |    ep_rew_mean          | 469          |
# | time/                   |              |
# |    fps                  | 8580         |
# |    iterations           | 12           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0042374926 |
# |    clip_fraction        | 0.0439       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.461       |
# |    explained_variance   | 0.366        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.174        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00244     |
# |    value_loss           | 0.623        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 492          |
# |    ep_rew_mean          | 492          |
# | time/                   |              |
# |    fps                  | 8538         |
# |    iterations           | 13           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0034406674 |
# |    clip_fraction        | 0.0504       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.462       |
# |    explained_variance   | 0.077        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.114        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00214     |
# |    value_loss           | 0.406        |
# ------------------------------------------

# %%
test_env = gym.make("CartPole-v1")

num_eval_episodes = 100
episode_lengths = []

for episode in range(num_eval_episodes):
    state, _ = test_env.reset()
    done = False
    steps = 0

    while not done:
        action, _ = model.predict(state, deterministic=True)
        state, reward, terminated, truncated, _ = test_env.step(action)
        done = terminated or truncated
        steps += 1

    episode_lengths.append(steps)

test_env.close()

average_steps = sum(episode_lengths) / num_eval_episodes
print(f"Average steps over {num_eval_episodes} episodes: {average_steps:.2f}")
# Out:
# Average steps over 100 episodes: 500.00
