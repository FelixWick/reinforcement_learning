# %%
! pip install gymnasium numpy matplotlib
# Out:
# Requirement already satisfied: gymnasium in /Users/wick/reinforcement_learning/.venv/lib/python3.13/site-packages (1.2.3)
# Requirement already satisfied: numpy in /Users/wick/reinforcement_learning/.venv/lib/python3.13/site-packages (2.4.2)
# Requirement already satisfied: matplotlib in /Users/wick/reinforcement_learning/.venv/lib/python3.13/site-packages (3.10.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/wick/reinforcement_learning/.venv/lib/python3.13/site-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/wick/reinforcement_learning/.venv/lib/python3.13/site-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/wick/reinforcement_learning/.venv/lib/python3.13/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/wick/reinforcement_learning/.venv/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/wick/reinforcement_learning/.venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/wick/reinforcement_learning/.venv/lib/python3.13/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/wick/reinforcement_learning/.venv/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/wick/reinforcement_learning/.venv/lib/python3.13/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /Users/wick/reinforcement_learning/.venv/lib/python3.13/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /Users/wick/reinforcement_learning/.venv/lib/python3.13/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/wick/reinforcement_learning/.venv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/wick/reinforcement_learning/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import numpy as np
import gymnasium as gym
import random
import matplotlib.pyplot as plt

# %% [markdown]
# https://gymnasium.farama.org/environments/toy_text/taxi/

# %%
env = gym.make("Taxi-v3")

# %%
state, _ = env.reset()
done = False
total_reward = 0

while not done:
    action = np.random.choice(env.action_space.n)
    state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    total_reward += reward

print("Total reward for random agent:", total_reward)

env.close()
# Out:
# Total reward for random agent: -677

# %%
import time

env = gym.make("Taxi-v3", render_mode="human")

state, _ = env.reset()
done = False
total_reward = 0

while not done:
    action = np.random.choice(env.action_space.n)
    state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    total_reward += reward
    time.sleep(0.5)   # Slow it down so you can see it

print("Total reward:", total_reward)
env.close()
