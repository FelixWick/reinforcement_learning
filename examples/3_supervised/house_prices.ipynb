# %%
! pip install pandas
! pip install scikit-learn
! pip install seaborn
# Out:
# Requirement already satisfied: pandas in /Users/wick/data_science/.venv/lib/python3.13/site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: scikit-learn in /Users/wick/data_science/.venv/lib/python3.13/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from scikit-learn) (2.4.2)
# Requirement already satisfied: scipy>=1.10.0 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: seaborn in /Users/wick/data_science/.venv/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/wick/data_science/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing

# %%
X, y = fetch_california_housing(return_X_y=True, as_frame=True)

# %%
X
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %% [markdown]
# The target variable is the median house value for California districts, expressed in hundreds of thousands of dollars ($100,000).

# %%
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: MedHouseVal, Length: 20640, dtype: float64

# %%
y.mean()
# Out:
# np.float64(2.0685581690891475)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
ml_est = RandomForestRegressor()

# %%
ml_est.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
yhat_train = ml_est.predict(X_train)

# %%
mean_absolute_error(y_train, yhat_train)
# Out:
# 0.12238536585513607

# %%
yhat_test = ml_est.predict(X_test)

# %%
mean_absolute_error(y_test, yhat_test)
# Out:
# 0.321379884520349

# %% [markdown]
# profile plots of correlation to target

# %%
for feature in X_train.columns:
    sns.regplot(x=X_train[feature], y=y_train, x_bins=100, fit_reg=None)
    sns.regplot(x=X_train[feature], y=yhat_train, x_bins=100, fit_reg=None, color="red")
    plt.show()

# %%
X["MedHouseVal"] = y
sns.scatterplot(
    data=X,
    x="Longitude",
    y="Latitude",
    size="MedHouseVal",
    hue="MedHouseVal",
    palette="viridis",
    alpha=0.5,
)
# Out:
# <Axes: xlabel='Longitude', ylabel='Latitude'>

# %% [markdown]
# try another method (less overfitting)

# %%
ml_est = HistGradientBoostingRegressor()

# just to avoid a joblib warning
import os
os.environ['OMP_NUM_THREADS'] = '1'

ml_est.fit(X_train, y_train)
# Out:
# HistGradientBoostingRegressor()

# %%
yhat_train = ml_est.predict(X_train)
mean_absolute_error(y_train, yhat_train)
# Out:
# 0.2750835572616934

# %%
yhat_test = ml_est.predict(X_test)
mean_absolute_error(y_test, yhat_test)
# Out:
# 0.3082092659294311

# %% [markdown]
# and more methods for comparison

# %%
from sklearn.tree import DecisionTreeRegressor

ml_est = DecisionTreeRegressor()
ml_est.fit(X_train, y_train)
yhat_train = ml_est.predict(X_train)
yhat_test = ml_est.predict(X_test)

print(mean_absolute_error(y_train, yhat_train))
print(mean_absolute_error(y_test, yhat_test))
# Out:
# 4.0772725419857976e-17
# 0.4487707364341086

# %% [markdown]
# the following methods need scaled features

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

ml_est = LinearRegression()
ml_est.fit(X_train, y_train)
yhat_train = ml_est.predict(X_train)
yhat_test = ml_est.predict(X_test)

print(mean_absolute_error(y_train, yhat_train))
print(mean_absolute_error(y_test, yhat_test))
# Out:
# 0.53392523761679
# 0.5262780037463892

# %%
from sklearn.neighbors import KNeighborsRegressor

ml_est = KNeighborsRegressor(n_neighbors=5)
ml_est.fit(X_train, y_train)
yhat_train = ml_est.predict(X_train)
yhat_test = ml_est.predict(X_test)

print(mean_absolute_error(y_train, yhat_train))
print(mean_absolute_error(y_test, yhat_test))
# Out:
# 0.35651309156976746
# 0.4341684752906977

# %%
from sklearn.svm import SVR

ml_est = SVR(kernel="rbf")
ml_est.fit(X_train, y_train)
yhat_train = ml_est.predict(X_train)
yhat_test = ml_est.predict(X_test)

print(mean_absolute_error(y_train, yhat_train))
print(mean_absolute_error(y_test, yhat_test))
# Out:
# 0.38492584298137256
# 0.3903057585865171
